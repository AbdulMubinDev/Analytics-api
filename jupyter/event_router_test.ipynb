# %%
import requests

path = '/api/events/1'
url = 'http://localhost:8000'
endpoint = f'{url}{path}'
endpoint
# Out:
# 'http://localhost:8000/api/events/1'

# %%
response = requests.get(endpoint)

if response.ok :
    data = response.json()
    print(data)
# Out:
# {'id': 1}
